# %%
from sympy import *

# %%
x = Symbol('x')

# %%
a = 5*x**2 + 10*x - 30

# %%
solveset(a)
# Out:
# {-1 + sqrt(7), -sqrt(7) - 1}

# %%
z = plot(a)

# %%
p = diff(a)
p
# Out:
# 10*x + 10

# %%
w = plot(p)
